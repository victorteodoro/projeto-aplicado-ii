# %% [markdown]
# <a href="https://colab.research.google.com/github/victorteodoro/projeto-aplicado-ii/blob/main/3_Prepara%C3%A7%C3%A3o_dos_dados_rotula%C3%A7%C3%A3o_dos_pixeis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Iniciando o programa através do modulo contido na URL
#
# **Antes de iniciar**, o programa abaixo usa token e senha de acesso ftp que não são públicos. Para garantir que apenas os envolvidos tenham acesso às funcionalidades com essas informações restritas, use a **chave de acesso** disponibilizada no material entregue pelo Canvas.
#
# Vamos incluir a classe **ProjetoCarcara** e suas dependencias que será detalhada no **Apendice 1**.

# %%
# !wget https://asav.com.br/carcara/modulo.py

with open("modulo.py", 'r') as file:
    exec(file.read())

import getpass

CKEY = getpass.getpass('Digite a chave de acesso: ')
# Out:
# --2024-03-28 15:34:37--  https://asav.com.br/carcara/modulo.py
# Resolving asav.com.br (asav.com.br)... 108.179.252.164
# Connecting to asav.com.br (asav.com.br)|108.179.252.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45136 (44K)
# Saving to: ‘modulo.py.7’
#
# modulo.py.7         100%[===================>]  44.08K  --.-KB/s    in 0.1s
#
# 2024-03-28 15:34:37 (411 KB/s) - ‘modulo.py.7’ saved [45136/45136]
#
# Digite a chave de acesso: ··········

# %% [markdown]
# # Acessando o projeto
#
# Vamos acessar o projeto já iniciado pelo FTP e salvo na pasta *2024-1-agua-e-vida-stl*.
#
# Em seguida, vamos mostrar a área de interesse (que corresponde ao município de São Thomé das Letras) e o _dataframe_ com a lista de mapas baixados.

# %%
projeto = ProjetoCarcara("2024-1-agua-e-vida-stl", ftp=ftplib.FTP("ftp.asav.com.br", "datascience@asav.com.br", CKEY))

display(projeto.area_interesse)
display(projeto.galeria)
# Out:
# [-21.88779, -21.60614, -45.09643, -44.82858]
#                        projeto  \
# 0  projects/earthengine-public
# 1  projects/earthengine-public
# 2  projects/earthengine-public
# 3  projects/earthengine-public
# 4  projects/earthengine-public
# 5  projects/earthengine-public
# 6  projects/earthengine-public
# 7  projects/earthengine-public
# 8  projects/earthengine-public
# 9  projects/earthengine-public
#
#                                              mapa_id        data      hora  \
# 0  COPERNICUS/S2/20240126T131241_20240126T131236_...  2024-01-26  13:18:00
# 1  COPERNICUS/S2/20240225T131241_20240225T131240_...  2024-02-25  13:18:23
# 2  COPERNICUS/S2/20230804T131249_20230804T131756_...  2023-08-04  13:18:29
# 3  COPERNICUS/S2/20220814T131301_20220814T131255_...  2022-08-14  13:18:36
# 4  COPERNICUS/S2/20210819T131251_20210819T131520_...  2021-08-19  13:18:26
# 5  COPERNICUS/S2/20200814T131251_20200814T131249_...  2020-08-14  13:18:30
# ...

# %% [markdown]
# Em seguida abrimos a imagem de um mapa salvo.
#
# No caso escolhemos o mapa de **índice 2**, de **4 de agosto de 2023**.
#
# Os mapas de 2 a 9, incluindo ambos, serão usados no projeto. Os mapas 0 e 1 fizeram parte dos testes iniciais do programa e seguem salvos no servidor.

# %%
abrir_mapa = 2  # escolhemos o mapa de índice 2

print(projeto.galeria['data'].iloc[abrir_mapa]+"\n")

imagem = projeto.abrirMapa(projeto.galeria['mapa_id'].iloc[abrir_mapa]) # imagem de satélite baixada
img=imagem.visualizarMapa(projeto.area_interesse[0], projeto.area_interesse[1], projeto.area_interesse[2], projeto.area_interesse[3])

mascara = imagem.mascaras['objeto'].iloc[0]

display(imagem.quadros)
# Out:
# 2023-08-04
# <PIL.Image.Image image mode=RGBA size=707x800>
#     indice_lat  indice_lon  salvo  \
# 0         -610       -1165   True
# 1         -610       -1164   True
# 2         -610       -1163   True
# 3         -610       -1162   True
# 4         -610       -1161   True
# ..         ...         ...    ...
# 67        -602       -1164   True
# 68        -602       -1163   True
# 69        -602       -1162   True
# 70        -602       -1161   True
# 71        -602       -1160   True
#
#                                                objeto  carregado
# 0   <__main__.QuadroSatelite object at 0x7d4966c39...       True
# 1   <__main__.QuadroSatelite object at 0x7d4966c39...       True
# 2   <__main__.QuadroSatelite object at 0x7d4966c38...       True
# 3   <__main__.QuadroSatelite object at 0x7d4966c6c...       True
# 4   <__main__.QuadroSatelite object at 0x7d4966c6c...       True
# ..                                                ...        ...
# ...

# %% [markdown]
# Escolha um quadro pelo índice à esquerda de 0 a 71:

# %%
escolhido = 27    # índice do quadro escolhido

quadro = imagem.quadros['objeto'].iloc[escolhido]

nome_do_arquivo = quadro.nome_do_arquivo()+".png"

display(nome_do_arquivo)

display(quadro.imagem)

print("\n-------------------------------\nCategorias e suas cores:\n")

display(mascara.categorias)

print("\n\n")

# Salva a imagem em um diretório temporário do Colab
quadro.imagem.save(nome_do_arquivo)  # Salva a imagem no sistema de arquivos do Colab

# Oferece o arquivo para download. O usuário será capaz de baixar a imagem com o nome especificado.
files.download(nome_do_arquivo)
# Out:
# 'S0000025fO0000048b.png'
# <PIL.Image.Image image mode=RGB size=400x400>
# -------------------------------
# Categorias e suas cores:
#    indice             nome     cor
# 0       1  área preservada  00ff00

# %% [markdown]
# Se for ele mesmo veja que o _download_ da imagem foi feito ao executar o script acima.
#
# Depois, use o Gimp, Photoshop ou semelhante para marcar as categorias em uma camada transparente por cima da imagem. Use as cores da categoria acima (representadas em hexadecial RGB) e salve em uma imagem _png_ com o nome original.
#
# Por fim, envie-la abaixo sem alterar o nome do arquivo, pois o nome referencia a posição hexadecimal do quadro. Os pixeis com menos de 50% de transparencia não serão considerados como categorias (categoria = 0). Os demais serão marcados com a categoria com a cor mais próxima a do pixel. A função abaixo converte a imagem para uma lista de _int_ representando as categorias de cada pixel da imagem original.
#
# **OBS:** Se você está apenas analisando o projeto e gostaria de ver o comando abaixo funcionar, use a imagem em:
#
# https://asav.com.br/carcara/S0000025fO0000048b.png

# %%
mascara.uploadImagemMascara()
# Out:
#      <input type="file" id="files-ecc325b2-0318-4186-aeb7-fe0a53d8ec67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecc325b2-0318-4186-aeb7-fe0a53d8ec67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Se a imagem original do quadro confere com a imagem que você rotulou, confirme a operação salvando o mapa abaixo:

# %%
#projeto.salvarMapa() # Deixei como comentário o comando para evitar corromper os dados do projeto já existente
